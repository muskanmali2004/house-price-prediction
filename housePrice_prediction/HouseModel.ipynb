# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: c:\Users\sweta\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: c:\Users\sweta\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: c:\Users\sweta\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: c:\Users\sweta\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.1.1
# [notice] To update, run: c:\Users\sweta\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder , StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
#
#    READY_TO_MOVE  RESALE                      ADDRESS  LONGITUDE   LATITUDE  \
# 0              1       1        Ksfc Layout,Bangalore  12.969910  77.597960
# 1              1       1    Vishweshwara Nagar,Mysore  12.274538  76.644605
# 2              1       1             Jigani,Bangalore  12.778033  77.632191
# 3              1       1  Sector-1 Vaishali,Ghaziabad  28.642300  77.344500
# 4              0       1             New Town,Kolkata  22.592200  88.484911
#
#    TARGET(PRICE_IN_LACS)
# 0                   55.0
# 1                   51.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29451 entries, 0 to 29450
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   POSTED_BY              29451 non-null  object
#  1   UNDER_CONSTRUCTION     29451 non-null  int64
#  2   RERA                   29451 non-null  int64
#  3   BHK_NO.                29451 non-null  int64
#  4   BHK_OR_RK              29451 non-null  object
#  5   SQUARE_FT              29451 non-null  float64
#  6   READY_TO_MOVE          29451 non-null  int64
#  7   RESALE                 29451 non-null  int64
#  8   ADDRESS                29451 non-null  object
#  9   LONGITUDE              29451 non-null  float64
#  10  LATITUDE               29451 non-null  float64
#  11  TARGET(PRICE_IN_LACS)  29451 non-null  float64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 2.7+ MB

# %%
df.isnull().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# ADDRESS                  0
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.select_dtypes(include = np.number).corr(),annot = True)
# Out:
# <Axes: >

# %%
filtered_df = df[df["SQUARE_FT"]<5000]
plt.figure(figsize=(10,5))
sns.histplot(filtered_df["SQUARE_FT"],bins = 50,kde = True)
# Out:
# <Axes: xlabel='SQUARE_FT', ylabel='Count'>

# %%
filtered_price = df[df["TARGET(PRICE_IN_LACS)"]<500]
sns.histplot(filtered_price["TARGET(PRICE_IN_LACS)"],bins=50,kde = True)
# Out:
# <Axes: xlabel='TARGET(PRICE_IN_LACS)', ylabel='Count'>

# %%
categorical_cols = ['POSTED_BY', 'BHK_OR_RK', 'UNDER_CONSTRUCTION', 'RERA', 'READY_TO_MOVE', 'RESALE']

for col in categorical_cols:
    plt.figure(figsize=(8,5))
    sns.boxplot(data=df, x=col, y='TARGET(PRICE_IN_LACS)', palette='Set2')
    plt.title(f'Price vs {col}')
    plt.ylabel('Price (Lacs ₹)')
    plt.xlabel(col)
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# C:\Users\sweta\AppData\Local\Temp\ipykernel_3756\3960378021.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=col, y='TARGET(PRICE_IN_LACS)', palette='Set2')
# C:\Users\sweta\AppData\Local\Temp\ipykernel_3756\3960378021.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=col, y='TARGET(PRICE_IN_LACS)', palette='Set2')
# C:\Users\sweta\AppData\Local\Temp\ipykernel_3756\3960378021.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x=col, y='TARGET(PRICE_IN_LACS)', palette='Set2')
# ...

# %%
filtered_df = df[df['SQUARE_FT'] < 5000]
plt.figure(figsize=(10, 5))
sns.histplot(filtered_df['SQUARE_FT'], bins=50, kde=True, color='skyblue')
plt.title('Square Footage Distribution')
plt.xlabel('Square Feet')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
avg_price = df.groupby("BHK_NO.")["TARGET(PRICE_IN_LACS)"].mean().reset_index()
sns.barplot(x="BHK_NO.",y="TARGET(PRICE_IN_LACS)",data = avg_price)
# Out:
# <Axes: xlabel='BHK_NO.', ylabel='TARGET(PRICE_IN_LACS)'>

# %%
df.head()
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
#
#    READY_TO_MOVE  RESALE                      ADDRESS  LONGITUDE   LATITUDE  \
# 0              1       1        Ksfc Layout,Bangalore  12.969910  77.597960
# 1              1       1    Vishweshwara Nagar,Mysore  12.274538  76.644605
# 2              1       1             Jigani,Bangalore  12.778033  77.632191
# 3              1       1  Sector-1 Vaishali,Ghaziabad  28.642300  77.344500
# 4              0       1             New Town,Kolkata  22.592200  88.484911
#
#    TARGET(PRICE_IN_LACS)
# 0                   55.0
# 1                   51.0
# ...

# %%
le = LabelEncoder()
df["POSTED_BY"]=le.fit_transform(df["POSTED_BY"])
df["BHK_OR_RK"]=le.fit_transform(df["BHK_OR_RK"])

df.drop(columns=["ADDRESS"],inplace=True)

# %%
X = df.drop(columns=["TARGET(PRICE_IN_LACS)"]) #Independent
y = df["TARGET(PRICE_IN_LACS)"] #Dependent

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(X_train,y_train)
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.3138424746500653

# %%
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
rmse
# Out:
# np.float64(552.2054321893526)

# %%
n = X_test.shape[0]
p = X_test.shape[1]
adjusted_r2 = 1 - (1-r2)*((n-1)/(n-p-1))
adjusted_r2
# Out:
# 0.3131356786824613

# %%
import pickle

# %%
with open('Model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
# Save the scaler
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
